# %%
 L = [1,2,3,4,5]
L.upper() # 'list' object has no attribute 'upper' ----> object
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1-1911563849.py in <cell line: 0>()
#       1 L = [1,2,3,4,5]
# ----> 2 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s = 'hello'
s.append(x) # 'str' object has no attribute 'append' ----> object
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2-3485590436.py in <cell line: 0>()
#       1 s = 'hello'
# ----> 2 s.append(x)
#
# AttributeError: 'str' object has no attribute 'append'

# %% [markdown]
# ## What is Procedural Programming?
# Procedural Programming is a way of writing programs by giving the computer a step-by-step set of instructions (called procedures or functions).
#
# ## Real life analogy
# Imagine you are cooking noodles using a recipe.
#
#  1. Boil Water
#  2. Add noodles
#  3. Stir for 5 minutes
#  4. Drain and Serve
#
# Here the program runs line by line, calling functions in order.
#
# ## When is procedural programming good?
# - Writing small scripts
# - Solving simple problems
# - Learning basic logic and structure
# - Quick automation tasks
#
# ## Why it fails?
# - Too many functions starts depending on each other.
# - Variables are reused, causing bugs.
# - No clear organization - hard to debug or upgrade.
#
#
# # Generality(Procedural) to Specificity(OOP)
#
# The main power of OOP is that it gives a programmer the power to create his own data types.

# %% [markdown]
# ![Screenshot 2025-07-08 211340.png](data:image/png;base64,...)
#
#
# ## Class- Class is a blueprint
# ## Object is an instance of Class

# %%
L = [1,2,3]
print(type(L)) # <class 'list'>
# Out:
# <class 'list'>

# %%
L.upper()
# L.upper() 'list' object has no attribute 'upper'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4-3930800027.py in <cell line: 0>()
# ----> 1 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %% [markdown]
# In Python, all the data types we study (like int, str, list, dict, etc.) are actually built-in classes. When we assign a value to a variable, Python internally creates an object of the corresponding class. So, for example, when we write x = 5, Python treats x as an object of the class int.
#
# ![Screenshot 2025-07-08 212050.png](data:image/png;base64,...)
#
# ![Screenshot 2025-07-08 212242.png](data:image/png;base64,...)
#
# A class is like a set of rules or a blueprint that defines what an object will have (attributes) and what it can do (methods).

# %% [markdown]
# ![Screenshot 2025-07-08 213402.png](data:image/png;base64,...)

# %% [markdown]
# ## Object Examples
# 1. Car ----> WagonR // wagonr = car()
# 2. Sports ----> Cricket // cricket = sports()
# 3. Animals ----> Lion // lion = animals()

# %%
# Syntax to create an object
# objectname = classname()

# %%
# object literal
L = [1,2,3]

# %%
L = list()
L
# Out:
# []

# %%
s = str()
s
# Out:
# ''

# %% [markdown]
# ## Class Naming
#
# ### Pascal Case - -> HelloWorld

# %%
class Atm:

  #constructor -> basically a function inside the class
  def __init__(self):
    self.pin = ''
    self.balance = 0

# %%
obj = Atm()

# %%
print(type(obj))
# Out:
# <class '__main__.Atm'>

# %%
class Atm:

  #constructor -> basically a function inside the class -> special function -> superpower -> we do not have to call it explicitly
  def __init__(self):
    self.pin = ''
    self.balance = 0
    print('Executed')

    def menu(self):
      user_input = input("""
      Hi there, how can I help you?
      1. Press 1 to create pin
      2. Press 2 to change pin
      3. Press 3 to check balance
      4. Press 4 to withdraw
      5. Anything else to exit
      """)

# %%
obj = Atm() #executed
# Out:
# Executed

# %%
class Atm:

  def __init__(self):
    self.pin = ''
    self.balance = 0
    self.menu()

  def menu(self):
      user_input = input("""
      Hi there, how can I help you?
      1. Press 1 to create pin
      2. Press 2 to change pin
      3. Press 3 to check balance
      4. Press 4 to withdraw
      5. Anything else to exit
      """)

# %%
obj2 = Atm()
# Out:
#       Hi there, how can I help you?
#       1. Press 1 to create pin
#       2. Press 2 to change pin
#       3. Press 3 to check balance
#       4. Press 4 to withdraw
#       5. Anything else to exit
#       1

# %%
class Atm:

  def __init__(self):
    self.pin = ''
    self.balance = 0
    self.menu()

  def menu(self):
      user_input = input("""
      Hi there, how can I help you?
      1. Press 1 to create pin
      2. Press 2 to change pin
      3. Press 3 to check balance
      4. Press 4 to withdraw
      5. Anything else to exit
      """)

      if user_input == '1':
        # create pin
        self.create_pin()
      elif user_input == '2':
        # change pin
        pass
      elif user_input == '3':
        # check balance
        pass
      elif user_input == '4':
        # withdraw
        pass
      else:
        exit()

  def create_pin(self):
    user_pin = input('Enter your pin: ')
    self.pin = user_pin

    user_balance = int(input('Enter balance: '))
    self.balance = user_balance

    print('pin created successfully')

# %%
obj = Atm()
# Out:
#       Hi there, how can I help you?
#       1. Press 1 to create pin
#       2. Press 2 to change pin
#       3. Press 3 to check balance
#       4. Press 4 to withdraw
#       5. Anything else to exit
#       1
# Enter your pin: 4587
# Enter balance: 10000
# pin created successfully

# %%
class Atm:

  def __init__(self):
    self.pin = ''
    self.balance = 0
    self.menu()

  def menu(self):
      user_input = input("""
      Hi there, how can I help you?
      1. Press 1 to create pin
      2. Press 2 to change pin
      3. Press 3 to check balance
      4. Press 4 to withdraw
      5. Anything else to exit
      """)

      if user_input == '1':
        self.create_pin()
      elif user_input == '2':
        self.change_pin()
      elif user_input == '3':
        pass
      elif user_input == '4':
        pass
      else:
        print("Thank you for using the ATM.")
        return

  def create_pin(self):
    user_pin = input('Enter your pin: ')
    self.pin = user_pin

    user_balance = int(input('Enter balance: '))
    self.balance = user_balance

    print('Pin created successfully')
    self.menu()

  def change_pin(self):
    old_pin = input('Enter old pin: ')  # changed from int()
    if old_pin == self.pin:
      new_pin = input('Enter new pin: ')  # changed from int()
      self.pin = new_pin
      print('Pin changed successfully')
      self.menu()
    else:
      print('Invalid pin')
      self.menu()

# %%
obj =Atm()
# Out:
#       Hi there, how can I help you?
#       1. Press 1 to create pin
#       2. Press 2 to change pin
#       3. Press 3 to check balance
#       4. Press 4 to withdraw
#       5. Anything else to exit
#       1
# Enter your pin: 5789
# Enter balance: 10000
# Pin created successfully
#
#       Hi there, how can I help you?
#       1. Press 1 to create pin
#       2. Press 2 to change pin
#       3. Press 3 to check balance
#       4. Press 4 to withdraw
#       5. Anything else to exit
#       1
# Enter your pin: 1487
# Enter balance: 1254
# Pin created successfully
#
#       Hi there, how can I help you?
#       1. Press 1 to create pin
#       2. Press 2 to change pin
#       3. Press 3 to check balance
#       4. Press 4 to withdraw
#       5. Anything else to exit
#       2
# Enter old pin: 1488
# Invalid pin
#
#       Hi there, how can I help you?
#       1. Press 1 to create pin
#       2. Press 2 to change pin
#       3. Press 3 to check balance
#       4. Press 4 to withdraw
# ...

# %%
class Atm:

  def __init__(self):
    self.pin = ''
    self.balance = 0
    self.menu()

  def menu(self):
    user_input = input("""
    Hi there, how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      print("Thank you for using the ATM.")
      return

  def create_pin(self):
    user_pin = input('Enter your pin: ')
    self.pin = user_pin

    user_balance = int(input('Enter balance: '))
    self.balance = user_balance

    print('Pin created successfully')
    self.menu()

  def change_pin(self):
    old_pin = input('Enter old pin: ')
    if old_pin == self.pin:
      new_pin = input('Enter new pin: ')
      self.pin = new_pin
      print('Pin changed successfully')
      self.menu()
    else:
      print('Invalid pin')
      self.menu()

  def check_balance(self):
    user_pin = input('Enter your pin: ')
    if user_pin == self.pin:
      print(f'Your balance is {self.balance}')
    else:
      print('Invalid Pin')
    self.menu()

  def withdraw(self):
    usr_pin = input('Enter your pin: ')
    if usr_pin == self.pin:
      amount = int(input('Enter the amount you want to withdraw: '))
      if amount <= self.balance:
        self.balance = self.balance - amount
        print('Withdrawal successful. Balance is', self.balance)
      else:
        print('Insufficient Balance')
    else:
      print('Invalid pin')
    self.menu()

# %%
obj = Atm()
# Out:
#     Hi there, how can I help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     1
# Enter your pin: 2508
# Enter balance: 5000
# Pin created successfully
#
#     Hi there, how can I help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     4
# Enter your pin: 6000
# Invalid pin
#
#     Hi there, how can I help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     4
# Enter your pin: 2508
# Enter the amount you want to withdraw: 6000
# Insufficient Balance
#
#     Hi there, how can I help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
# ...

# %%
L = [1,2,3,5]
len(L) # -> just a normal function
L.append(4) # .append -> method -> function written inside a class

# %%
class Fraction:
  def __init__(self,x,y):
    self.num = x
    self.den = y

  def __str__(self):
    return '{}/{}'.format(self.num, self.den)

# %%
frac1 = Fraction(3,4)
frac2 = Fraction(2,3)
print(frac1, type(frac1))
print(frac2, type(frac2))
# Out:
# 3/4 <class '__main__.Fraction'>
# 2/3 <class '__main__.Fraction'>

# %%
print(frac1 + frac2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-5-360536598.py in <cell line: 0>()
# ----> 1 print(frac1 + frac2)
#
# TypeError: unsupported operand type(s) for +: 'Fraction' and 'Fraction'

# %%
# parametrized constructor

class Fraction:
  def __init__(self,x,y):
    self.num = x
    self.den = y

  def __str__(self):
    return '{}/{}'.format(self.num, self.den)

  def __add__(self,other):
    new_num = self.num*other.den + other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num, new_den)

# %%
fr1 = Fraction(4,5)
fr2 = Fraction(2,5)
print(fr1)
print(fr2)
# Out:
# 4/5
# 2/5

# %%
print(fr1 + fr2)
# Out:
# 30/25

# %%
print(fr1 - fr2) # write the entire logic
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-9-658299665.py in <cell line: 0>()
# ----> 1 print(fr1 - fr2)
#
# TypeError: unsupported operand type(s) for -: 'Fraction' and 'Fraction'

# %%
class Fraction:
  def __init__(self,x,y):
    self.num = x
    self.den = y

  def __str__(self):
    return '{}/{}'.format(self.num, self.den)

  def __add__(self,other):
    new_num = self.num*other.den + other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num, new_den)

  def __sub__(self,other):
    new_num = self.num*other.den - other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num, new_den)

# %%
fr1 = Fraction(4,6)
fr2 = Fraction(9,2)
print(fr1 - fr2)
# Out:
# -46/12

# %%
# Fraction data type

class Fraction:
  def __init__(self,x,y):
    self.num = x
    self.den = y

  def __str__(self):
    return '{}/{}'.format(self.num, self.den)

  def __add__(self,other):
    new_num = self.num*other.den + other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num, new_den)

  def __sub__(self,other):
    new_num = self.num*other.den - other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num, new_den)

  def __mul__(self,other):
    new_num = self.num * other.num
    new_den = self.den * other.den

    return '{}/{}'.format(new_num, new_den)

  def __truediv__(self,other):
    new_num = self.num*other.den
    new_den = self.den*other.num

    return '{}/{}'.format(new_num, new_den)

  def convert_to_decimal(self):
    return self.num/self.den

# %%
fr1 = Fraction(2,3)
fr2 = Fraction(6,5)
print(fr1 + fr2)
print(fr1 - fr2)
print(fr1 * fr2)
print(fr1 / fr2)
# Out:
# 28/15
# -8/15
# 12/15
# 10/18

# %%
fr1.convert_to_decimal()
# Out:
# 0.6666666666666666
